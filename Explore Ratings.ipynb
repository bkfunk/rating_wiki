# %%
import numpy as np
import pandas as pd
from functools import partial

# %%
from pylab import *
import matplotlib.pyplot as plt
from scipy import stats

# %%
# %matplotlib inline

# %%
def ttest_group(data, by, var):
    g = data.groupby(by)[var]
    keys = g.groups.keys()
    res = pd.DataFrame(data=np.empty(shape=(len(g.groups), 2*len(g.groups))),
                       index=g.groups.keys(),
                       columns=pd.MultiIndex.from_product([['t stat.','p-value'], g.groups.keys()], names=[var, by]),
                       dtype='object')
    #res.index.name = by
    #res.columns.name = by
    for key1 in keys:
        for key2 in keys:
            if key1 == key2:
                res.loc[key1, ('t stat.', key2)] = "x"
                res.loc[key1, ('p-value', key2)] = "x"
            else:
                res.loc[key1, ('t stat.', key2)] = "%0.2f" % stats.ttest_ind(g.get_group(key1), g.get_group(key2))[0]
                res.loc[key1, ('p-value', key2)] = "%0.3f" % stats.ttest_ind(g.get_group(key1), g.get_group(key2))[1]
    return res

# %%
import warnings
def desc(data, 
         float_decimals=3, 
         stats=['count','mean','std','min','percentiles','max'], percentiles=[25,50,75]):
    """Get a DataFrame with statistical aggregations of a DataFrame"""
    
    # Create empty columns list
    cs = []
    # Calculate each of the statistics
    for stat in stats:
        if isinstance(stat, str):
            if stat == 'count':
                cs.append(pd.DataFrame(data.count(), columns=['count'])) 
            elif stat == 'mean':
                cs.append(pd.DataFrame(data.mean(), columns=['mean'])) 
            elif stat == 'std':
                cs.append(pd.DataFrame(data.std(), columns=['std']))
            elif stat == 'min':
                cs.append(pd.DataFrame(data.min(), columns=['min'])) 
            elif stat == 'max':
                cs.append(pd.DataFrame(data.max(), columns=['max']))
            elif stat == 'percentiles' or stat == 'pct':
                pctiles = data.dropna().apply(partial(np.percentile, q=percentiles))
                cs.append(pd.DataFrame.from_records(pctiles.tolist(),
                                                    index = pctiles.index,
                                                    columns = map(lambda x: '%d%%' % x, percentiles))) # add "%" to end of each element
            else:
                warnings.warn("No known procedure for statistic '%s'; "
                              "only 'count', 'mean', 'std', 'min', 'percentiles' or 'pct', and 'max' are supported" % stat)
        else:
            cs.append(data.apply(stat))
    
    # Concat all the stat DataFrames
    d = pd.concat(cs, axis=1)
    # Change float columns to formatted strings (to reduce number of decimals according to float_decimals)
    for c in d.loc[:, d.dtypes == np.float].columns:
        d[c] = d[c].apply(lambda x: ('{:0.%df}' % float_decimals).format(x))
    return d

# %% [markdown]
# # Introduction #
#
# What defines a _good_ or _effective_ article on Wikipedia?
#
# But to ask that question, we must also ask: What is the _purpose_ of a Wikipedia article? But again, this question forces another: What do people go to Wikipedia _for_? For, if we know why users _use_ Wikipedia, it makes sense to then say that the purpose of its articles is to satisfy the needs of the users, and thus an effective article is one which satisfies the needs of those who visit it. (It should be noted, explicitly, of course, that I am here considering the _users_ to primarily be those who _read_ Wikipedia, rather than those who _edit_ it—though of course editors are also users in this sense, just a small proportion of them; if Wikipedia is conceived of as primarily a _community of editors_, a sort of virtual hobby whose purpose is to satisfy the hobbyists, then the above questions become much less significant and, I believe, so does Wikipedia itself.)
#
# I argue that Wikipedia users go to Wikipedia for reasons that, often, could be roughly broken down into 3 categories:
# 1. _To learn_: a user is curious about a concept, or they are researching an assignment, or they have come across something they don't understand. These users want a brief description of what they are looking for, a sort of long-form definition. Often, such users are not experts in the article's broader field, and thus are looking for a description that is understandable for the layperson:
#     + It does not exessively use vocabulary that is not defined or introduced clearly.
#     + It does not define the subject of the article solely based upon other concepts with which the user is similarly unfamiliar.
#     + It clearly explains not only _what_ the subject is, but _why_ it is significant in the broader context (an area that, when I have been using Wikipedia in this way, I have found to be lacking).
#
# 2. _To find information_: a user is looking for a particular fact or detail—Who is so-and-so married to? When did so-and-so die? When _was_ the Battle of Such-and-such? This of course could be seen as a subset of #1 (and in fact so could all uses), but I distinguish it because, in this case, the user _knows what he or she wants to find_. They know that So-and-so is a public figure, they just don't know who So-and-so's spouse is. These users often don't need to read the articles themselves: much of the factual information is summarized in the infoboxes. What is the electronegativity of platinum? Note that such a user would never search for that information if they did not already know:
#     + What platinum is
#     + What electronegativity is
#     + Why one would need to know the electronegativity of an element
#
# 3. _To remember what has been forgotten_: a user is refreshing their understanding of a subject. Again, this could be a subset of both #1 and #2, but I distinguish it because, unlike #1, the user is already quite familiar with the material, and unlike #2, the user is looking for something that is not a clear-cut fact which could be listed in an infobox. For example: When do I use a one-tailed t-test vs. a two-tailed one? Where was the epigraph to _The Waste Land_ from? How many of Wittgenstein's brothers committed suicide? What was the precipitating event of the Opium Wars? This user will make use of the section headings and perhaps look for a certain phrase in the page, skimming until the information is found. Again, this user knows a fair amount about the subject, as well as how the subject relates to the broader context.
#
# Though all related, these use cases for Wikipedia are, I think, quite distinct, insofar as each will be looking in different parts of the article (e.g. #1 will read the introduction more than #2 or #3 will, #2 will consult the infobox primarily, while the others may ignore it, and #3 may pay close attention to the contents to find the relevant section). Each will also judge the article differently. #1 will likely value clarity of writing, as well as comprehensiveness, but may not have the background to really judge how objective or trustworth an article is (though of course they will notice the extent to which citations are used, etc.). #2 may not read any of the writing, but will notice if key facts are left out. #3 will rely extensively on the article being well organized as well as complete and comprehensive.
#
# Which leads me to: How can (should) we interpret readers' subjective ratings of Wikipedia articles? Can the overall quality of an article be measured by looking at the mean of various readers' ratings? Is there even such a thing as _overall quality_ in this context?

# %% [markdown]
# 1. Are ratings meaningful? Does the rating of one user correlate to the rating of other users?
# 2. Are the rating dimensions meaningful? Do people actually judge separate components of an article, or do they simply record a sort of binary good/bad, all-1s/all-5s opinion?
# 3. Do articles get better over time?
# 4. Does the size (or other measure of magnitude—perhaps reputation of the editor, e.g.) of an edit affect how it changes an article's rating? Does size, for example, improve completeness more than it does trustworthiness or writing quality? Does the number of citations make an article more trustworthy or objective?

# %% [markdown]
# ## Load data ##

# %%
df = pd.read_csv('cleaned_wiki_ratings.csv')

# %% [markdown]
# ## 1. Ratings per page/Ratings per version ##

# %% [markdown]
# ### 1a - Which page has the most ratings?

# %%
r = df.groupby('page_title').page_rate_count.max()
r.describe()
# Out:
# count    10000.000000
# mean         7.852400
# std         42.055952
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max       2713.000000
# Name: page_rate_count, dtype: float64

# %%
r.sort(ascending=False)
r.head(10)
# Out:
# page_title
# The_Hunger_Games                             2713
# List_of_spells_in_Harry_Potter               1685
# Abraham_Lincoln                              1389
# Marilyn_Monroe                                663
# Dhirubhai_Ambani                              596
# OSI_model                                     567
# Knights_Templar                               553
# Arithmetic_progression                        442
# United_States_Declaration_of_Independence     439
# Business_development                          408
# Name: page_rate_count, dtype: int64

# %% [markdown]
# Ha, the Hunger Games! Not very surprising. Some of the others are interesting, though! (Knights Templar?!)
#
# __NB:__ Of course, this is a **_sample_**, so this does not really say much about the world itself.
#
# Let's look at a plot of the distribution:

# %%
fig = plt.figure()
r.sort() # sort ascending and take the tail so that the top bar on the plot is the highest of the group
ax = r.tail(20).plot(
    kind='barh',
    title='Most Rated Pages',
    figsize=(10, 8))
ax.set_xlabel('Number of Ratings')

# %% [markdown]
# And let's look at the overall distribution.

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18,5))

for i, section, title in [(0, r, 'All Pages'), 
                (1, r.iloc[-100:], 'Pages w/ Most Ratings'),
                (2, r.iloc[0:-100], 'Pages w/ Fewest Ratings')] :
    section.hist(ax=axes[i], 
           normed=True,
           bins=math.sqrt(section.count()),
           color='lightskyblue',
           alpha=0.7)
    section.plot(ax=axes[i],
                 kind='kde',
                 xlim=(section.min(), section.max()),
                 title="%s (N=%d)" % (title, section.count()))

fig.suptitle("Distribution of Ratings per Page")
#fig.tight_layout()

# %% [markdown]
# The right-tadistribution is hardly surprising, though the drop-off is quite sharp, as the most-rated pages tend to be rated many times more than the next-most-rated.

# %% [markdown]
# -----
# ### 1b - Which pages have the most rated versions?
#
# More versions means that we have more rated edits, and thus can trace the article quality over a greater history.
#
# **NB:** I distinguish between "versions" and "rated versions" (or in some cases "versions rated") because I am using data from the ratings dataset only, at this stage. Any versions of the page that don't have any ratings are thus invisible in this dataset; there is no way, for example, to look at the number of edits made to a page, only the number of _edits that have been rated_.

# %%
v = df.groupby('page_title').rev_id.unique().apply(lambda x: x.size)
v.describe()
# Out:
# count    10000.000000
# mean         3.661200
# std         10.193802
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max        580.000000
# dtype: float64

# %%
v.sort(ascending=False)
v.head(10)
# Out:
# page_title
# The_Hunger_Games                      580
# Abraham_Lincoln                       250
# Marilyn_Monroe                        169
# MDNA_(album)                          157
# OSI_model                             145
# The_Amazing_Spider-Man_(2012_film)    135
# Knights_Templar                       134
# House_of_Night                        130
# Thirteen_Reasons_Why                  129
# Ice_hockey                            124
# dtype: int64

# %% [markdown]
# Some clear similarities with __1a__.

# %%
fig = plt.figure()
v.sort()
ax = v.tail(20).plot(
    kind='barh',
    title='Pages with Most Versions Rated',
    figsize=(10, 8))
ax.set_xlabel('Number of Versions Rated')

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,5))

for i, section, title in [(0, v, 'All Pages'), 
                (1, v.iloc[-100:], 'Pages w/ Most Versions Rated'),
                (2, v.iloc[0:-100], 'Pages w/ Fewest Versions Rated')] :
    section.hist(ax=axes[i], 
           normed=True,
           bins=min(math.sqrt(section.count()), len(section.unique())),
           color='lightskyblue',
           alpha=0.7)
    section.plot(ax=axes[i],
                 kind='kde',
                 xlim=(section.min(), section.max()),
                 title="%s (N=%d)" % (title, section.count()))

fig.suptitle("Distribution of Rated Versions per Page")
#fig.tight_layout()

# %% [markdown]
# -----
# ### 1c - Ratings Per Version
#
# Ratings per version gives us a measure of the information we have for each version, i.e. how reliable the ratings are.

# %%
rpv = r / v
rpv.describe()
# Out:
# count    10000.000000
# mean         1.626829
# std          1.403800
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         40.119048
# dtype: float64

# %%
rpv.sort(ascending=False)
rpv.head(10)
# Out:
# page_title
# List_of_spells_in_Harry_Potter         40.119048
# Syn_and_anti_addition                  30.000000
# Tool_pusher                            25.000000
# Alan_Questel                           23.200000
# MS_Contin                              22.500000
# Group_technology                       22.000000
# Arc_elasticity                         21.000000
# The_Other_Side_of_the_Sky:_A_Memoir    20.000000
# Cultural_lag                           17.000000
# Cultural_institutions                  17.000000
# dtype: float64

# %% [markdown]
# This is interesting! Not what you'd expect. RPV can be conceived as the view velocity divided by the editing velocity, i.e. the number of views per edit (there're a lot of assumptions underlying that conception of course).

# %%
fig = plt.figure()
rpv.sort()
ax = rpv.tail(20).plot(
    kind='barh',
    title='Pages with Highest Ratings-Per-Version-Rated',
    figsize=(10, 8))
ax.set_xlabel('Ratings per version')

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,5))

for i, section, title in [(0, rpv, 'All Pages'), 
                (1, rpv.iloc[-100:], 'Pages w/ Highest RPV'),
                (2, rpv.iloc[0:-100], 'Pages w/ Lowest RPV')] :
    section.hist(ax=axes[i], 
           normed=True,
           bins=math.sqrt(section.count()),
           color='lightskyblue',
           alpha=0.7)
    section.plot(ax=axes[i],
                 kind='kde',
                 xlim=(section.min(), section.max()),
                 title="%s (N=%d)" % (title, section.count()))

fig.suptitle("Distribution of Ratings-Per-Version-Rated per Page")
#fig.tight_layout()

# %% [markdown]
# Note that, because this is a quotient, there are bumps at `p/q`.

# %% [markdown]
# ------------------
# ## 2. Page Ratings
#
# ### 2a - What is the distribution of page ratings?
# Let's look at the distribution of all ratings. First we'll look at `ratings_all_mean` (the mean of all dimensions _only when all dimensions are present_, and `ratings_any_mean` (the mean of any dimensions that are present). We'll also look at the number of dimensions rated.

# %%
#bins = [1,1.5,2,2.5,3,3.5,4,4.5,5]
#bins = [0.75,1.25, 1.75, 2.25, 2.75, 3.25, 3.75, 4.25, 4.75, 5.25]
bins=8
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))
# Means
for i, var in enumerate(['rating_all_mean', 'rating_any_mean']):
    df[var].dropna().hist(ax=axes[i],
                            normed=True,
                            bins=bins,
                            color='lightskyblue',
                            alpha=0.7)
    df[var].dropna().plot(ax=axes[i],
                            kind='kde',
                            xlim=(1,5),
                            title=var)

# Number of dimensions per rating
dim_counts = df.groupby(['rating_dim_count']).page_id.count() / df.page_id.count()
dim_counts
#if True:
dim_counts.plot(ax=axes[2],
                    kind='bar',
                    color='lightskyblue',
                    alpha=0.7,
                    title="Distribution of Dimensions Rated")

# %% [markdown]
# So, __most people rate all 4 dimensions, and most articles are rated as `5` across all dimensions__. There is also a significant minority who give all `1`s.

# %% [markdown]
# ----
# ### 2b What does it mean if a user does not rate all dimensions?
#
# Why would a user only rate one (or two, or three) dimensions? Perhaps they feel they are not qualified to judge one or more aspects of an article. Or, perhaps they only care about particular dimensions; maybe, for example, a user doesn't believe "trustworthiness" is discernable from "objectivity", and thus they only rate one of those. Does the distribution of ratings change based on how many dimensions are rated? For example, perhaps people rate one dimension when they find something particularly egregious, and so they tend to give poor ratings.
#
# Let's look at the distribution of `rating_any_mean` by number of rated dimensions.

# %%
#bins = [1,1.5,2,2.5,3,3.5,4,4.5,5,5.5]
#bins = [0.75,1.25, 1.75, 2.25, 2.75, 3.25, 3.75, 4.25, 4.75, 5.25]
bins=8
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(16, 4))

for i, d in enumerate([1,2,3,4]):
    axes[i].hist(df[df.rating_dim_count==d].rating_any_mean.values, normed=False, bins=bins, align='mid')
    axes[i].set_title("Dimensions Rated = %d" % d)

fig.suptitle('Distribution of rating_any_mean',
             size='large', weight='bold', va='bottom')

# Output description
df.groupby('rating_dim_count').rating_any_mean.describe().unstack()
# Out:
#                   count      mean       std  min       25%  50%       75%  max
# rating_dim_count
# 1                 19535  3.841157  1.498986    1  3.000000    5  5.000000    5
# 2                  2124  3.436441  1.478599    1  2.000000    4  5.000000    5
# 3                  2775  3.531291  1.318520    1  2.666667    4  4.666667    5
# 4                 53303  3.658185  1.343684    1  2.750000    4  5.000000    5
#
# [4 rows x 8 columns]

# %% [markdown]
# So it appears that __users who rate only one dimension tend to rate that dimension more highly__. Let's do a t-test to make sure:

# %%
ttest_group(df, by='rating_dim_count', var='rating_any_mean')
# Out:
# rating_any_mean  t stat.                      p-value
# rating_dim_count       1      2      3      4       1      2      3      4
# 1                      x  11.83  10.34  15.77       x  0.000  0.000  0.000
# 2                 -11.83      x  -2.37  -7.43   0.000      x  0.018  0.000
# 3                 -10.34   2.37      x  -4.85   0.000  0.018      x  0.000
# 4                 -15.77   7.43   4.85      x   0.000  0.000  0.000      x
#
# [4 rows x 8 columns]

# %% [markdown]
# ----
# ### 2c - What are the distributions of each dimension?
#
# Now let's look at each particular dimension. Are users more forgiving on some dimensions vs. others?

# %%
dims = ['comp', 'obj', 'trust', 'writ']
nonmiss = df.loc[:,dims].count() / len(df)
nonmiss.name = 'pct not missing'
d = df.loc[:,dims].describe()
pd.concat([pd.DataFrame(count).T, d]).T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1035-ed655307adfa> in <module>()
#       3 nonmiss.name = 'pct not missing'
#       4 d = df.loc[:,dims].describe()
# ----> 5 pd.concat([pd.DataFrame(count).T, d]).T
#
# NameError: name 'count' is not defined

# %% [markdown]
# So it appears that __"completeness" tends to be rated lower than other dimensions__, while __"well-written" tends to be rated higher__. Also, __fewer users rate "objectivity", while more users rate "well-written"__.
#
# Let's look at histograms of ratings for each dimension.

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(12, 4))

for i, d in enumerate(dims):
    gs = df.groupby([d])
    rtgs = df[d].dropna().count()
    x = gs[d].count() / rtgs
    x.plot(ax = axes[i], kind='bar', ylim=(0,.5))
    axes[i].set_title(d)

fig.suptitle('Proportion of Each Rating')

# %% [markdown]
# ----
# ### 2d - How is each dimension related to the others?
#
# Are dimensions correlated? We already know that a lot of users give all `5`s. But perhaps some dimensions are more correlated with others?

# %%
for method in ['pearson', 'spearman']:
    print "%s Correlation" % method
    print df[dims].corr(method)
# Out:
# pearson Correlation
#            comp       obj     trust      writ
# comp   1.000000  0.715450  0.749500  0.764108
# obj    0.715450  1.000000  0.774930  0.738221
# trust  0.749500  0.774930  1.000000  0.753312
# writ   0.764108  0.738221  0.753312  1.000000
#
# [4 rows x 4 columns]
# spearman Correlation
#            comp       obj     trust      writ
# comp   1.000000  0.704479  0.735459  0.759818
# obj    0.704479  1.000000  0.751640  0.703651
# trust  0.735459  0.751640  1.000000  0.725299
# writ   0.759818  0.703651  0.725299  1.000000
#
# [4 rows x 4 columns]

# %% [markdown]
# As we might expect, __"objective" is correlated most highly with "trustworthy"__. Perhaps less expected, __"complete" and "well-written" are also more correlated with each other than they are with the other dimensions__. These are both true whether we look at normal Pearson correlation or whether we use Spearman's *rho* rank correlation coefficient. Still, __all dimmensions are highly (positively) correlated with each other__.

# %% [markdown]
# ----
# ### 2e - How consistent are ratings for particular pages/versions?
#
# Ideally, ratings would cluster pretty closely for a particular page, and certainly for a particular version. If ratings are truly meaningful to the community as a whole (vs. to a certain individual or a small group), then users should be able to come to some sort of consensus about the quality of a particular page. We will explore this issue more deeply in section 3 (Page Rating Histories), but here we can look at some general statistics.
#
# We'll start by looking at the distribution of ratings around the mean rating. First, I'll focus on ratings that have all four dimensions, since I suspect that such ratings will be of higher quality (on the assumption that someone rating all four dimensions is more likely to actually _consider_ all dimensions -- though of course it is also possible that people who rate the same across the board are actually bringing _less_ consideration to the process).
#
# We will also only look at pages with at least 3 ratings, and then pages with at least 50 ratings, and finally with at least 300 ratings.

# %% [markdown]
# Group ratings by page and by version (revision), and calculate the mean and median of `rating_all_mean`, as well as the count of ratings with all dimensions rated.
#
# __NB:__ `rating_all_mean` is the mean of across all _rating dimensions_, while `page_all_mean` (or `page_comp_mean`, etc.) is the mean of `rating_all_mean` (or `comp`, etc.) across all rating-rows for each page.

# %%
p_ratings = df.groupby('page_title')
df['page_all_mean'] = p_ratings.rating_all_mean.transform('mean') # the per-page mean of `rating_all_mean`
df['page_all_median'] = p_ratings.rating_all_mean.transform('median') # the per-page median of `rating_all_mean`
df['page_all_rate_count'] = p_ratings.rating_all_mean.transform('count') # the per-page count of non-null `rating_all_mean`
                                                                        # i.e. the count of rows with all 4 dimensions
for dim in dims: # means for each rating dimension (comp/trust/obj/writ)
    df['page_%s_mean' % dim] = p_ratings[dim].transform('mean')
    #df['page_%s_median' % dim] = p_ratings[dim].transform('median')

# %%
# Do same as above, but this time grouping by VERSION (aka revision)
v_ratings = df.groupby('rev_id')
df['rev_all_mean'] = v_ratings.rating_all_mean.transform('mean')
df['rev_all_median'] = v_ratings.rating_all_mean.transform('median')
df['rev_all_rate_count'] = v_ratings.rating_all_mean.transform('count')
for dim in dims:
    df['rev_%s_mean' % dim] = v_ratings[dim].transform('mean')
    #df['rev_%s_median' % dim] = v_ratings[dim].transform('median')

# %% [markdown]
# For each page and version, compute difference variables for:
# + __Difference __between a particular rating value (either `rating_all_mean` or a single rating dimension value) and
#     + the __mean__ for all observations for that page/version (with all 4 rating dimensions)
#     + the __median__ for all observations for that page/version (with all 4 rating dimensions)
# + And, the __absolute value__ of those difference variables (so we can comute the average absolute deviation, etc.)

# %%
for unit in ['page', 'rev']:
    for avg in ['mean', 'median']:
        df['diff_%s_all_%s' % (unit, avg)] = df.rating_all_mean - df['%s_all_%s' % (unit, avg)]
        df['absdif_%s_all_%s' % (unit, avg)] = abs(df.rating_all_mean - df['%s_all_%s' % (unit, avg)])
        if avg == 'mean':
            for dim in dims:
                df['diff_%s_%s_%s' % (unit, dim, avg)] = df[dim] - df['%s_%s_%s' % (unit, dim, avg)]
                df['absdif_%s_%s_%s' % (unit, dim, avg)] = abs(df[dim] - df['%s_%s_%s' % (unit, dim, avg)])

# %% [markdown]
# Let's look first at the _average absolute deviations_ for each page/version, using both mean and median as our measure of central tendency.

# %%
desc(df[df.page_all_rate_count >= 2].filter(regex='absdif_page.*')).sort()
# Out:
#                         count   mean    std    min    25%    50%    75%    max
# absdif_page_all_mean    49712  0.956  0.722  0.000  0.395  0.820  1.333  3.640
# absdif_page_all_median  49712  0.905  0.881  0.000  0.250  0.625  1.250  4.000
# absdif_page_comp_mean   55500  1.126  0.759  0.000  0.500  1.056  1.612  3.667
# absdif_page_obj_mean    53265  1.103  0.780  0.000  0.500  1.000  1.512  3.809
# absdif_page_trust_mean  56986  1.117  0.787  0.000  0.519  1.000  1.530  3.833
# absdif_page_writ_mean   60508  1.040  0.762  0.000  0.500  0.893  1.375  3.820
#
# [6 rows x 8 columns]

# %%
desc(df[df.rev_all_rate_count >= 2].filter(regex='absdif_rev.*')).sort()
# Out:
#                        count   mean    std    min    25%    50%    75%    max
# absdif_rev_all_mean    34515  0.817  0.671  0.000  0.275  0.649  1.200  3.784
# absdif_rev_all_median  34515  0.758  0.829  0.000  0.125  0.500  1.125  4.000
# absdif_rev_comp_mean   37403  0.960  0.739  0.000  0.400  0.833  1.500  3.682
# absdif_rev_obj_mean    36317  0.933  0.755  0.000  0.333  0.750  1.400  3.875
# absdif_rev_trust_mean  38216  0.958  0.766  0.000  0.333  0.800  1.500  3.818
# absdif_rev_writ_mean   39920  0.902  0.735  0.000  0.333  0.727  1.333  3.818
#
# [6 rows x 8 columns]

# %% [markdown]
# So, the spread of ratings within each version is smaller than within each page, which makes sense. Still, the spread is relatively large, with each dimension, for example, being, on average, almost a whole point away from the mean. For cases where there are 2 ratings for a certain version, this means that, on average, those ratings are separated by nearly 2 whole points, since their mean is their midpoint: a 5 and a 3, say, or a 4 and a 2.
#
# What happens when we change the cutoff?
#
# First, let's look at the distribution of the counts of pages and versions with all dimensions rated.

# %%
desc(df.filter(like='all_rate_count'), float_decimals=1, percentiles=[5,10,25,50,75,90,95]).sort().T
# Out:
#       page_all_rate_count rev_all_rate_count
# count               78524              78524
# mean                172.5                5.4
# std                 437.4               12.7
# min                   0.0                0.0
# 5%                    1.0                0.0
# 10%                   2.0                0.0
# 25%                   6.0                1.0
# 50%                  22.0                2.0
# 75%                  93.0                5.0
# 90%                 313.0               11.0
# 95%                1304.0               22.0
# max                2110.0              141.0
#
# [12 rows x 2 columns]

# %% [markdown]
# Now, I'll plot the average absolute deviations across cutoffs.

# %%
from matplotlib.ticker import FuncFormatter 
l = []
n = []
count = len(df)
cutoffs = range(2,252)
for cutoff in cutoffs:
    l.append(df[df.page_all_rate_count >= cutoff].filter(regex='absdif_page.*').mean())
    n.append(100 * len(df[df.page_all_rate_count >= cutoff])/float(len(df)))

aad = pd.DataFrame(l, index=cutoffs)
n_line = pd.Series(n, name='n', index=cutoffs)

fig, ax = plt.subplots(figsize=(14,12))
ax1 = aad.plot(ax=ax, linewidth=2, sort_columns=True,
         title="Change in Average Absolute Deviation based on Minimum Number of Ratings per Page")
ax1.yaxis.set_label_text('Average Absolute Deviation')
ax1.xaxis.set_label_text('Cutoff')
ax1.legend(loc="upper right")

ax2 = n_line.plot(ax=ax, secondary_y=True, label="N", alpha=.5, style='k--', )
ax2.yaxis.set_label_text('% of Ratings Satisfying Cutoff', rotation=-90)
ax2.yaxis.labelpad = 16
def pct_fmt(x, pos=0): 
    return '%d%%'%(x)
ax2.yaxis.set_major_formatter(FuncFormatter(pct_fmt))
ax2.legend(loc='lower left')

# %%
l = []
n = []
count = len(df)
cutoffs = range(2,52)
for cutoff in cutoffs:
    l.append(df[df.rev_all_rate_count >= cutoff].filter(regex='absdif_rev.*').mean())
    n.append(100 * len(df[df.rev_all_rate_count >= cutoff])/float(len(df)))

aad = pd.DataFrame(l, index=cutoffs)
n_line = pd.Series(n, name='n', index=cutoffs)

fig, ax = plt.subplots(figsize=(10,8))
ax1 = aad.plot(ax=ax, linewidth=2, sort_columns=True,
         title="Change in Average Absolute Deviation based on Minimum Number of Ratings per Version")
ax1.yaxis.set_label_text('Average Absolute Deviation')
ax1.xaxis.set_label_text('Cutoff')
ax1.legend(loc="upper right")

ax2 = n_line.plot(ax=ax, secondary_y=True, label="N", alpha=.5, style='k--', )
ax2.yaxis.set_label_text('% of Ratings Satisfying Cutoff', rotation=-90)
ax2.yaxis.labelpad = 16
def pct_fmt(x, pos=0): 
    return '%d%%'%(x)
ax2.yaxis.set_major_formatter(FuncFormatter(pct_fmt))
ax2.legend(loc='lower left')

# %% [markdown]
# It appears that restricting our sample to pages/versions with more observations initially __increases__ then __steadily decreases__ the spread of values around the mean/median. (More on what that might mean below.)

# %% [markdown]
# Here are the same statistics as presented in the above tables, only now for the _non-absolute_ differences:

# %%
desc(df[df.page_all_rate_count >= 2].filter(like='diff_page')).sort()
# Out:
#                       count    mean    std     min     25%    50%    75%  \
# diff_page_all_mean    49712   0.000  1.198  -3.640  -0.667  0.226  0.917
# diff_page_all_median  49712  -0.256  1.237  -4.000  -0.750  0.000  0.500
# diff_page_comp_mean   55500   0.000  1.358  -3.667  -1.000  0.167  1.086
# diff_page_obj_mean    53265  -0.000  1.351  -3.809  -0.844  0.329  1.023
# diff_page_trust_mean  56986   0.000  1.367  -3.833  -0.876  0.370  1.000
# diff_page_writ_mean   60508   0.000  1.289  -3.820  -0.727  0.353  0.933
#
#                         max
# diff_page_all_mean    3.357
# diff_page_all_median  4.000
# diff_page_comp_mean   3.556
# diff_page_obj_mean    3.643
# diff_page_trust_mean  3.333
# diff_page_writ_mean   3.333
#
# [6 rows x 8 columns]

# %%
desc(df[df.rev_all_rate_count >= 2].filter(like='diff_rev')).sort()
# Out:
#                      count    mean    std     min     25%    50%    75%    max
# diff_rev_all_mean    34515   0.000  1.057  -3.784  -0.600  0.083  0.694  3.543
# diff_rev_all_median  34515  -0.139  1.115  -4.000  -0.625  0.000  0.500  4.000
# diff_rev_comp_mean   37403   0.000  1.212  -3.682  -0.750  0.000  0.875  3.500
# diff_rev_obj_mean    36317  -0.000  1.200  -3.818  -0.667  0.000  0.833  3.875
# diff_rev_trust_mean  38216  -0.000  1.227  -3.818  -0.667  0.000  0.840  3.692
# diff_rev_writ_mean   39920  -0.000  1.163  -3.818  -0.667  0.114  0.800  3.333
#
# [6 rows x 8 columns]

# %% [markdown]
# Note that the `mean` column here is not meaningful (except perhaps for the `diff_*_all_median` rows), since the mean of the difference from the mean is, of course, 0. Of greater interest is the interquartile range, which shows a consistent rightward skew, with the exception of the differences based on median.
#
# Let's explore these distributions further with some histograms at various cutoffs.

# %%
cols = df.filter(like='diff_page').columns.values # list of columns starting with 'diff_page'
cols.sort()

for cutoff in [2, 93, 313]:
    # Restrict data to:
    # - columns of interest
    # - rows that have all rating dimensions
    # - only for pages with number of ratings above cutoff
    d = df.loc[(df.rating_all_mean.notnull()) & (df.page_all_rate_count >= cutoff), cols]
    
    # Create subplot for each col variable
    fig, axes = plt.subplots(nrows=1, ncols=len(cols), figsize=(4*len(cols), 5), sharey=True)

    # Loop through the columns, plot a histogram and also a kernal density plot on top
    for i, var in enumerate(cols):
        d[var].dropna().hist(ax=axes[i],
                                normed=True,
                                bins=math.log(d[var].count()),
                                color='lightskyblue',
                                alpha=0.7)
        d[var].dropna().plot(ax=axes[i],
                                kind='kde',
                                linewidth=2,
                                xlim=(-5,5),
                                ylim=(0,1),
                                title=var)
    fig.suptitle("Distribution of rating deviation from page-wide mean/median - At least %d ratings with all dimensions" % cutoff, 
                 size='large', weight='bold', va='bottom')

# %% [markdown]
# So, all of these plots show a rightward skew, meaning that more people rate slightly higher than the mean, while some people rate significantly lower than the mean. This makes sense given the fact that the mean rating is fairly hight and the rating scale is truncated.
#
# The more meaningful factor is the _spread_, giving an indication of how consistent the ratings are. There is a consistent bimodal pattern here, which could indicate that ratings are not, in fact, centered on a single mean. There may be, say, two types of people rating articles, with each type having significantly different evaluation metrics and models.
#
# Another aspect to note is that __pages with greater numbers of ratings do not seem to lose this bimodality__; if anything, the bimodality is *__strengthened__*, indicating that it is not a problem of low N, but rather a consistent pattern. In fact, it is even possible that articles with many ratings are __more controversial__, meaning a greater variance (indicated in this case by bimodality).
#
# Looking at versions (using a different set of cutoffs), we see similar patterns:

# %%
cols = df.filter(like='diff_rev').columns.values
cols.sort()

for cutoff in [2, 5, 11]:
    d = df.loc[(df.rating_all_mean.notnull()) & (df.rev_all_rate_count >= cutoff), cols]
    fig, axes = plt.subplots(nrows=1, ncols=len(cols), figsize=(4*len(cols), 5), sharey=True)

    for i, var in enumerate(cols):
        d[var].dropna().hist(ax=axes[i],
                                normed=True,
                                bins=math.log(d[var].count()),
                                color='lightskyblue',
                                alpha=0.7)
        d[var].dropna().plot(ax=axes[i],
                                kind='kde',
                                linewidth=2,
                                xlim=(-5,5),
                                ylim=(0,1),
                                title=var)
    fig.suptitle("Distribution of rating deviation from version-wide mean/median - At least %d ratings with all dimensions per version" % cutoff, 
                 size='large', weight='bold', va='bottom')

# %% [markdown]
# ----
# ### 2f - Do users who are logged in rate pages differently?
#
# If we assume that logged-in users are more savvy about Wikipedia standards and the stated goals of each page, then it might be true that such logged-in users would have more "accurate" (in the sense of _reflecting the a priori standards of Wikipedia_) ratings. They might also be expected to have ratings that are more closely linked

# %%
dims.extend(["a", "b"])

# %%
pcols = ['rating_all_mean', 'rating_any_mean']
pcols.extend(dims)
pcols
# Out:
# ['rating_all_mean',
#  'rating_any_mean',
#  'comp',
#  'obj',
#  'trust',
#  'writ',
#  'a',
#  'b']

# %%
d = df.groupby('logged_in')
for i, (k, v) in enumerate(d.groups.items()):
    print i
    print k
    print df.ix[v, 1:10].count()
    print df.iloc[v, 1:10].count()
# Out:
# 0
# 0.0
# rev_id        76509
# nth_rating    76509
# page_id       76509
# page_title    76509
# logged_in     76509
# datetime      76509
# comp          58543
# obj           55837
# trust         60231
# dtype: int64
# rev_id        76509
# nth_rating    76509
# page_id       76509
# page_title    76509
# logged_in     76509
# datetime      76509
# comp          58543
# obj           55837
# trust         60231
# dtype: int64
# 1
# 1.0
# rev_id        2015
# nth_rating    2015
# page_id       2015
# page_title    2015
# logged_in     2015
# datetime      2015
# comp          1720
# obj           1659
# trust         1762
# dtype: int64
# rev_id        2015
# nth_rating    2015
# page_id       2015
# page_title    2015
# logged_in     2015
# datetime      2015
# comp          1720
# obj           1659
# trust         1762
# dtype: int64

# %%
#bins = [1,1.5,2,2.5,3,3.5,4,4.5,5,5.5]
#bins = [0.75,1.25, 1.75, 2.25, 2.75, 3.25, 3.75, 4.25, 4.75, 5.25]
bins=8
pcols = ['rating_all_mean', 'rating_any_mean']
dims = ['comp', 'obj', 'trust', 'writ']
pcols.extend(dims)

fig, axes = plt.subplots(nrows=2, ncols=len(pcols), figsize=(16, 6), sharex=False, sharey=False)

login_gs = df.groupby('logged_in')

for r, (k, d) in enumerate(login_gs.groups.items()):
    for c, var in enumerate(pcols):
        # For continuous variables (with >10 unique values), make histogram
        if len(df.loc[d, var].unique()) > 10:
            df.loc[d, var].hist(ax=axes[r, c], normed=True, bins=bins, align='mid')
            if r == 0:
                axes[r,c].set_title(var)
        # For discrete variables, just plot frequency of each option
        else:
            gs = df.loc[d].groupby(var)
            rtgs = df.loc[d, var].dropna().count()
            x = gs[var].count() / rtgs
            x.plot(ax = axes[r, c], kind='bar', ylim=(0,.5))
            if r == 0:
                axes[r, c].set_title(var)
                axes[r, c].set_xlabel("")
        
'''
for i, d in enumerate(dims):
    gs = df.groupby([d])
    rtgs = df[d].dropna().count()
    x = gs[d].count() / rtgs
    x.plot(ax = axes[i], kind='bar', ylim=(0,.5))
    axes[i].set_title(d)
'''
#fig.suptitle('Proportion of Each Rating')
# Out:
#                  count   mean    std    min    25%    50%    75%    max
# rating_all_mean  51720  3.654  1.347  1.000  2.750  4.000  5.000  5.000
# rating_any_mean  75738  3.691  1.394  1.000  2.750  4.000  5.000  5.000
# comp             58543  3.398  1.549  1.000  2.000  4.000  5.000  5.000
# obj              55837  3.707  1.494  1.000  3.000  4.000  5.000  5.000
# trust            60231  3.714  1.519  1.000  3.000  4.000  5.000  5.000
# writ             63784  3.811  1.418  1.000  3.000  4.000  5.000  5.000
#
# [6 rows x 8 columns]
# "\nfor i, d in enumerate(dims):\n    gs = df.groupby([d])\n    rtgs = df[d].dropna().count()\n    x = gs[d].count() / rtgs\n    x.plot(ax = axes[i], kind='bar', ylim=(0,.5))\n    axes[i].set_title(d)\n"

# %% [markdown]
# * Print tables comparing logged-in, do t-tests

# %% [markdown]
# ## 3. Page Rating History

# %% [markdown]
# Before we can look at the page rating history, we need a sense of a "version" that is consistent across pages. The most sensible solution at this point (since we haven't merged in actual revision data from the Wiki DB) is to use _`nth_version`_. Thus, each _rating_ can be seen as a piece of information about a particular _version_, with the _versions_ themselves being the true "observations".
#
# First we merge in the RPV values for each rating.

# %%
df = pd.merge(left=df, right=pd.DataFrame(rpv, columns=['rpv']), left_on='page_title', right_index=True)
df = df.drop('Unnamed: 0', 1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78524 entries, 0 to 78523
# Data columns (total 62 columns):
# rev_id                    78524 non-null float64
# nth_rating                78524 non-null int64
# page_id                   78524 non-null int64
# page_title                78524 non-null object
# logged_in                 78524 non-null float64
# datetime                  78524 non-null object
# comp                      60263 non-null float64
# obj                       57496 non-null float64
# trust                     61993 non-null float64
# writ                      65568 non-null float64
# rating_dim_count          77737 non-null float64
# rating_any_mean           77737 non-null float64
# rating_all_mean           53303 non-null float64
# page_rate_count           78524 non-null int64
# rev_rate_count            78524 non-null float64
# page_comp_mean            77283 non-null float64
# rev_comp_mean             72232 non-null float64
# page_obj_mean             76953 non-null float64
# rev_obj_mean              71014 non-null float64
# page_trust_mean           77490 non-null float64
# rev_trust_mean            72943 non-null float64
# page_writ_mean            77450 non-null float64
# rev_writ_mean             74095 non-null float64
# page_all_mean             76417 non-null float64
# diff_page_all_mean        53303 non-null float64
# diff_page_comp_mean       60263 non-null float64
# diff_page_obj_mean        57496 non-null float64
# diff_page_trust_mean      61993 non-null float64
# diff_page_writ_mean       65568 non-null float64
# page_all_rate_count       78524 non-null float64
# rev_all_mean              69028 non-null float64
# rev_all_rate_count        78524 non-null float64
# diff_rev_all_mean         53303 non-null float64
# diff_rev_comp_mean        60263 non-null float64
# diff_rev_obj_mean         57496 non-null float64
# diff_rev_trust_mean       61993 non-null float64
# diff_rev_writ_mean        65568 non-null float64
# page_all_median           76417 non-null float64
# rev_all_median            69028 non-null float64
# page_comp_medianan        77283 non-null float64
# page_obj_medianan         76953 non-null float64
# page_trust_medianan       77490 non-null float64
# page_writ_medianan        77450 non-null float64
# rev_comp_medianan         72232 non-null float64
# rev_obj_medianan          71014 non-null float64
# rev_trust_medianan        72943 non-null float64
# rev_writ_medianan         74095 non-null float64
# diff_page_all_median      53303 non-null float64
# diff_rev_all_median       53303 non-null float64
# absdif_page_all_mean      53303 non-null float64
# absdif_page_comp_mean     60263 non-null float64
# absdif_page_obj_mean      57496 non-null float64
# absdif_page_trust_mean    61993 non-null float64
# absdif_page_writ_mean     65568 non-null float64
# absdif_page_all_median    53303 non-null float64
# absdif_rev_all_mean       53303 non-null float64
# absdif_rev_comp_mean      60263 non-null float64
# absdif_rev_obj_mean       57496 non-null float64
# absdif_rev_trust_mean     61993 non-null float64
# absdif_rev_writ_mean      65568 non-null float64
# absdif_rev_all_median     53303 non-null float64
# rpv                       78524 non-null float64
# dtypes: float64(57), int64(3), object(2)

# %% [markdown]
# Now we need to create the `nth_version` variable to index versions.

# %%
versions = df[['page_title','rev_id','nth_rating']].groupby(['page_title', 'rev_id']).first().reset_index()
versions['nth_version'] = versions.groupby(['page_title']).cumcount() + 1

# %% [markdown]
# Now merge versions into the main dataframe.

# %%
df = pd.merge(left=df, right=versions.drop('nth_rating', 1), left_on=['page_title', 'rev_id'], right_on=['page_title', 'rev_id'])

# %% [markdown]
# ### _Definition of FEFR Sample_ ###
#
# To look more closely at the data, we will examine **frequently edited, frequently rated (FEFR)** pages:
# + with at least 5 rated versions (i.e. "revisions" or edits)
# + with the highest ratings per rated version
#
# These pages have some amount of history, with a fair amount of information for each version in the history. Note, however, that both the number of _rated versions_ (i.e. versions that are in our data) **and** the _ratings per rated version (RPV)_ are not necessarily exogenous; in other words, it is quite possible that pages with many versions (and thus many edits), or high RPV, may be different in key and thusfar unobserved ways from other pages. For example, these pages might be more controversial; we can imagine that controversial pages would cause people to rate pages they strongly disagree with _and also_ to edit those pages, thus affecting both measures I use to define the sample. However, it is difficult, for example, to have confidence in the mean rating if there are only a handful of ratings for a particular page version. Thus, I'll leave the investigation of how representative these frequently edited, frequently rated pages are of Wikipedia pages in general until a later stage, when I have incorporated data from the Wiki DB itself.

# %%
df['page_rev_count'] = df.groupby('page_title').nth_version.transform('max')

# %%
fe_rpv = df[df.page_rev_count >= 5].groupby('page_title').rpv.first()
fe_rpv.sort(ascending=False)
fefr = df.set_index('page_title').loc[fe_rpv.head(20).index].reset_index()

# %% [markdown]
# Here is a list of the 20 FEFR pages:

# %%
fefr.sort(['page_title', 'nth_version', 'nth_rating'])
fefr.groupby('page_title')[['page_rev_count', 'page_rate_count', 'rpv']].mean()
# Out:
#                                            page_rev_count  page_rate_count  \
# page_title
# Acidic_oxide                                            6               53
# Alan_Questel                                            5              116
# Arithmetic_progression                                 40              442
# Business_development                                   26              408
# Carbon_copy                                             7              110
# Damp_proofing                                          10               77
# Excess-3                                                5               66
# Game_server                                             8               73
# Homework                                               18              203
# Implied_powers                                         21              170
# List_of_spells_in_Harry_Potter                         42             1685
# Multitenancy                                            7               65
# Ornamental_plant                                        9               77
# Partnership_accounting                                  6               57
# Pen_pal                                                14              126
# Pulse_Polio                                            10               84
# Singaporean_national_referendum,_1962                   7               56
# Ultra-high-definition_television                       35              272
# United_States_Declaration_of_Independence              52              439
# Zung_Self-Rating_Anxiety_Scale                          6               47
#
#                                                  rpv
# page_title
# Acidic_oxide                                8.833333
# Alan_Questel                               23.200000
# Arithmetic_progression                     11.050000
# Business_development                       15.692308
# Carbon_copy                                15.714286
# Damp_proofing                               7.700000
# Excess-3                                   13.200000
# Game_server                                 9.125000
# Homework                                   11.277778
# Implied_powers                              8.095238
# List_of_spells_in_Harry_Potter             40.119048
# Multitenancy                                9.285714
# Ornamental_plant                            8.555556
# Partnership_accounting                      9.500000
# Pen_pal                                     9.000000
# Pulse_Polio                                 8.400000
# Singaporean_national_referendum,_1962       8.000000
# Ultra-high-definition_television            7.771429
# United_States_Declaration_of_Independence   8.442308
# Zung_Self-Rating_Anxiety_Scale              7.833333
#
# [20 rows x 3 columns]

# %%
x = fefr.loc[fefr.page_title=='United_States_Declaration_of_Independence', ['datetime', 'rating_all_mean', 'rev_id']]
#y = fefr[fefr.page_title=='United_States_Declaration_of_Independence'].rating_all_mean
#ts = pd.Series(y, index=x)
x = x.set_index('datetime')
x.rating_all_mean.plot(figsize=(15,5), marker='o', linestyle='')

# %%
pages = fefr.groupby('page_title')
#revs = fefr.groupby('page_title').rev_id
#pd.merge(pd.DataFrame.from_dict({'first': revs.first(), columns=['First']), pd.DataFrame(revs.last(), columns=['Last']), 
#         left_on='First', right_on='Last')

pd.DataFrame.from_dict({'first': pages.rev_id.first(), 'last': pages.rev_id.last(), 'page_id': pages.page_id.first()})
# Out:
#                                                first       last   page_id
# page_title
# Acidic_oxide                               427061939  500154456    794849
# Alan_Questel                               485856064  490388040  35344096
# Arithmetic_progression                     439795331  499085638    168389
# Business_development                       439743024  501765668   4522229
# Carbon_copy                                439434682  498533853    240128
# Damp_proofing                              432333340  496300260   7094834
# Excess-3                                   434543512  474299975    457830
# Game_server                                439839963  497489178   3505526
# Homework                                   440714547  500086023    326546
# Implied_powers                             420335952  501842696   1602548
# List_of_spells_in_Harry_Potter             440252234  500539016   3284182
# Multitenancy                               438799944  502073454   3157360
# Ornamental_plant                           436098180  491862710    216428
# Partnership_accounting                     440550672  479834488  16789362
# Pen_pal                                    438856013  500418856     24537
# Pulse_Polio                                441492532  479155548   1104894
# Singaporean_national_referendum,_1962      395108968  484949665   1820005
# Ultra-high-definition_television           441055808  498702845   3086987
# United_States_Declaration_of_Independence  440924612  500818030     31874
# Zung_Self-Rating_Anxiety_Scale             430519224  480106228   6186270
#
# [20 rows x 3 columns]

# %%
from wikitools import wiki, api
site = wiki.Wiki('http://en.wikipedia.org/w/api.php')
params = {'action':'query', 
          'titles':'Acidic_oxide',
          'prop': 'revisions',
          'rvprop': 'ids',#|flags|timestamp|user|userid|size|comment|parsedcomment|content|tags|flagged',
          'rvlimit': 100,
          'rvdir': 'newer',
          'rvstartid':'427061939',
          'rvendid': '500154456'}
request = api.APIRequest(site, params)
result = request.query()
result
# Out:
# {u'query': {u'normalized': [{u'from': u'Acidic_oxide',
#     u'to': u'Acidic oxide'}],
#   u'pages': {u'794849': {u'ns': 0,
#     u'pageid': 794849,
#     u'revisions': [{u'parentid': 389194926, u'revid': 427061939},
#      {u'parentid': 427061939, u'revid': 445967216},
#      {u'parentid': 445967216, u'revid': 453935315},
#      {u'parentid': 453935315, u'revid': 462203723},
#      {u'parentid': 462203723, u'revid': 490775320},
#      {u'parentid': 490775320, u'revid': 490775470},
#      {u'parentid': 490775470, u'revid': 500154295},
#      {u'parentid': 500154295, u'revid': 500154456}],
#     u'title': u'Acidic oxide'}}}}

# %%
# Out:
# {u'794849': {u'ns': 0,
#   u'pageid': 794849,
#   u'revisions': [{u'parentid': 389194926, u'revid': 427061939},
#    {u'parentid': 427061939, u'revid': 445967216},
#    {u'parentid': 445967216, u'revid': 453935315},
#    {u'parentid': 453935315, u'revid': 462203723},
#    {u'parentid': 462203723, u'revid': 490775320},
#    {u'parentid': 490775320, u'revid': 490775470},
#    {u'parentid': 490775470, u'revid': 500154295},
#    {u'parentid': 500154295, u'revid': 500154456}],
#   u'title': u'Acidic oxide'}}

# %%
fefr.sort('page_rev_count', ascending=False)
foo = fefr.groupby('page_title', sort=True).page_title.first()
print foo
for title in foo:
    nversions = len(fefr.loc[fefr.page_title==title, 'nth_version'].unique())
    print title, nversions
    #ax = fefr[fefr.page_title==title].boxplot('rating_all_mean', by='nth_version', figsize=(15,3))
    #ax.set_ylim((1,5))
# Out:
# page_title
# Acidic_oxide                                                              Acidic_oxide
# Alan_Questel                                                              Alan_Questel
# Arithmetic_progression                                          Arithmetic_progression
# Business_development                                              Business_development
# Carbon_copy                                                                Carbon_copy
# Damp_proofing                                                            Damp_proofing
# Excess-3                                                                      Excess-3
# Game_server                                                                Game_server
# Homework                                                                      Homework
# Implied_powers                                                          Implied_powers
# List_of_spells_in_Harry_Potter                          List_of_spells_in_Harry_Potter
# Multitenancy                                                              Multitenancy
# Ornamental_plant                                                      Ornamental_plant
# Partnership_accounting                                          Partnership_accounting
# Pen_pal                                                                        Pen_pal
# Pulse_Polio                                                                Pulse_Polio
# Singaporean_national_referendum,_1962            Singaporean_national_referendum,_1962
# Ultra-high-definition_television                      Ultra-high-definition_television
# United_States_Declaration_of_Independence    United_States_Declaration_of_Independence
# Zung_Self-Rating_Anxiety_Scale                          Zung_Self-Rating_Anxiety_Scale
# Name: page_title, dtype: object
# Acidic_oxide 6
# Alan_Questel 5
# Arithmetic_progression 40
# Business_development 26
# Carbon_copy 7
# Damp_proofing 10
# Excess-3 5
# Game_server 8
# Homework 18
# Implied_powers 21
# List_of_spells_in_Harry_Potter 42
# Multitenancy 7
# Ornamental_plant 9
# Partnership_accounting 6
# Pen_pal 14
# Pulse_Polio 10
# Singaporean_national_referendum,_1962 7
# Ultra-high-definition_television 35
# United_States_Declaration_of_Independence 52
# Zung_Self-Rating_Anxiety_Scale 6

# %%
ax = fefr.loc[fefr.page_title=='United_States_Declaration_of_Independence'].boxplot('rating_any_mean', 
                                                                                    by='nth_version', 
                                                                                    figsize=(15,5))
ax.set_ylim((1,5))
a.plot(ax=ax)
#a.plot(ax=ax)
ad.plot(ax=ax)
#c.plot(ax=ax)
#o.plot(ax=ax)
#t.plot(ax=ax)
#w.plot(ax=ax)

#sd.plot(ax=ax)
#u.plot(ax=ax)
#l.plot(ax=ax, label='lower')
ax.legend()

# %%
fefr.filter(like='absdif')
# Out:
#     absdif_page_all_mean  absdif_page_comp_mean  absdif_page_obj_mean  \
# 0               0.337807               0.337809              0.613602
# 1               0.162193               0.337809              0.613602
# 2               0.587807               0.662191              0.613602
# 3                    NaN                    NaN                   NaN
# 4               0.087807               0.662191              1.386398
# 5                    NaN                    NaN                   NaN
# 6               0.587807               0.662191              0.613602
# 7               0.587807               0.662191              0.613602
# 8                    NaN                    NaN                   NaN
# 9               0.087807               0.337809              0.613602
# 10              1.162193               0.662191              2.386398
# 11              0.662193               0.662191              1.386398
# 12              0.587807               0.662191              0.613602
# 13                   NaN                    NaN                   NaN
# 14              0.587807               0.662191              0.613602
# 15                   NaN                    NaN              3.386398
# 16              0.912193               0.337809              1.386398
# 17              0.587807               0.662191              0.613602
# 18              0.587807               0.662191              0.613602
# 19              0.587807               0.662191              0.613602
# 20              0.412193               1.337809              0.613602
# 21                   NaN               0.337809                   NaN
# 22              0.162193               0.662191              0.613602
# 23              0.337807               0.662191              0.386398
# 24              1.162193               3.337809              0.613602
# 25                   NaN               0.337809                   NaN
# 26              0.587807               0.662191              0.613602
# 27              0.587807               0.662191              0.613602
# 28              0.087807               0.337809              0.386398
# 29              0.087807               0.337809              0.613602
# 30              0.587807               0.662191              0.613602
# 31              0.337807               0.337809              0.613602
# 32                   NaN                    NaN                   NaN
# 33              0.087807               1.337809              0.613602
# 34                   NaN                    NaN                   NaN
# 35              0.587807               0.662191              0.613602
# 36              1.662193               1.337809              3.386398
# 37                   NaN               0.337809                   NaN
# 38                   NaN                    NaN                   NaN
# 39              0.337807               0.662191              0.613602
# 40              0.162193               0.337809              0.386398
# 41              0.412193               1.337809              0.386398
# 42              0.087807               0.662191              0.613602
# 43              0.587807               0.662191              0.613602
# 44                   NaN                    NaN                   NaN
# 45                   NaN                    NaN                   NaN
# 46              0.087807               0.337809              0.613602
# 47              0.412193               0.337809              0.386398
# 48              0.412193               3.337809              0.613602
# 49              0.662193               0.337809              2.386398
# 50              0.412193               0.337809              1.386398
# 51              0.587807               0.662191              0.613602
# 52              0.337807               0.662191              0.386398
# 53              1.912193               0.337809              1.386398
# 54              0.337807               0.337809              0.613602
# 55              0.162193               0.662191              1.386398
# 56              0.412193               0.337809              0.386398
# 57                   NaN                    NaN                   NaN
# 58              0.587807               0.662191              0.613602
# 59              0.162193               0.662191              0.386398
#                      ...                    ...                   ...
#
#     absdif_page_trust_mean  absdif_page_writ_mean  absdif_page_all_median  \
# 0                 0.557772               0.531291                    0.00
# 1                 0.442228               0.468709                    0.50
# 2                 0.557772               0.531291                    0.25
# 3                 0.442228                    NaN                     NaN
# 4                 0.557772               0.531291                    0.25
# 5                 0.557772                    NaN                     NaN
# 41               0.571429              0.479167                   0.50
# 42               0.428571              0.479167                   0.00
# 43               0.571429              0.520833                   0.50
# 44                    NaN              0.520833                    NaN
# 45               0.571429                   NaN                    NaN
# 46               0.428571              0.520833                   0.00
# 47               0.428571              0.479167                   0.50
# 48               0.571429              0.520833                   0.50
# 49               0.571429              0.479167                   0.75
# 50               0.428571              0.520833                   0.50
# 51               0.571429              0.520833                   0.50
# 52               0.571429              0.520833                   0.25
# 53               2.428571              3.479167                   2.00
# 54               0.571429              0.520833                   0.25
# 55               0.571429              0.479167                   0.25
# 56               0.571429              1.479167                   0.50
# 57                    NaN              0.520833                    NaN
# 58               0.571429              0.520833                   0.50
# 59               0.428571              0.479167                   0.25
#                       ...                   ...                    ...
#
# [4626 rows x 12 columns]

# %%
m = fefr[fefr.page_title=='United_States_Declaration_of_Independence'].groupby('nth_version').rating_any_mean.mean()
a = fefr[fefr.page_title=='United_States_Declaration_of_Independence'].groupby('nth_version').rating_all_mean.mean()
sd = fefr[fefr.page_title=='United_States_Declaration_of_Independence'].groupby('nth_version').rating_any_mean.std()
u = fefr[fefr.page_title=='United_States_Declaration_of_Independence'].groupby('nth_version').rating_any_mean.quantile(.95)
l = fefr[fefr.page_title=='United_States_Declaration_of_Independence'].groupby('nth_version').rating_any_mean.quantile(.05)
c = fefr[fefr.page_title=='United_States_Declaration_of_Independence'].groupby('nth_version').comp.mean()
o = fefr[fefr.page_title=='United_States_Declaration_of_Independence'].groupby('nth_version')['obj'].mean()
t = fefr[fefr.page_title=='United_States_Declaration_of_Independence'].groupby('nth_version').trust.mean()
w = fefr[fefr.page_title=='United_States_Declaration_of_Independence'].groupby('nth_version').writ.mean()

ad = fefr[fefr.page_title=='United_States_Declaration_of_Independence'].groupby('nth_version').absdif_rev_all_mean.mean()

# %% [markdown]
# # TODO
# * create boxplots for all 20 FEFV
# * restyle boxplots so taht means are more prominent (connected?)
# * look into getting edit size

# %%
fig, axes = plt.subplots(nrows=len(groups), ncols=1, figsize=(15,20))

axes[0].add_axes(ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-770-608c884cdb6d> in <module>()
#       1 fig, axes = plt.subplots(nrows=len(groups), ncols=1, figsize=(15,20))
#       2
# ----> 3 axes[0].add_axes(ax)
#
# AttributeError: 'AxesSubplot' object has no attribute 'add_axes'

# %%
rpv.sort(ascending=False)
rpv.head(20).index
# Out:
# Index([u'List_of_spells_in_Harry_Potter', u'Syn_and_anti_addition', u'Tool_pusher', u'Alan_Questel', u'MS_Contin', u'Group_technology', u'Arc_elasticity', u'The_Other_Side_of_the_Sky:_A_Memoir', u'Cultural_lag', u'Cultural_institutions', u'Self-determination_of_Australian_Aborigines', u'Carbon_copy', u'Business_development', u'Suhas_Gopinath', u'Tudor_Gunasekara', u'Cross_subsidization', u'Inamgaon', u'Media_planner', u'Excess-3', u'Beck_Hopelessness_Scale'], dtype='object')

# %%
hrpv = df.set_index('page_title').loc[rpv.head(20).index].reset_index()

# %%
for i, x, v in enumerate(hrpv.groupby('page_title').groups.items()):
    print(i)
    print(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-670-dd5629d29094> in <module>()
# ----> 1 for i, x, v in enumerate(hrpv.groupby('page_title').groups.items()):
#       2     print(i)
#       3     print(x)
#
# ValueError: need more than 2 values to unpack

# %%
pages = hrpv.groupby('page_title')
groups = pages.groups.items()

# %%
groups[0][0]
# Out:
# 'Media_planner'

# %%
#fig, axes = plt.subplots(nrows=len(groups), ncols=1, figsize=(15,20))
#print axes
ax1 = hrpv.loc[groups[0][1]].boxplot(column='rating_all_mean', by='nth_version')
ax2 = hrpv.loc[groups[1][1]].boxplot(column='rating_all_mean', by='nth_version')
fig, axes = plt.subplots(nrows=len(groups), ncols=1, figsize=(15,20))

# %%
for i, g in enumerate(groups):
    #r, c = divmod(i, 4)
    print g[0]
    hrpv.loc[g[1]].boxplot(column='rating_all_mean', by='nth_version')
    #hrpv[hrpv.page_title == g[0]].boxplot(column='rating_all_mean', by=['nth_version'], ax=axes[r, c])
# Out:
# Media_planner
# Excess-3
# Alan_Questel
# Tudor_Gunasekara
# Cross_subsidization
# MS_Contin
# Inamgaon
# Self-determination_of_Australian_Aborigines
# Beck_Hopelessness_Scale
# Carbon_copy
# Suhas_Gopinath
# Business_development
# List_of_spells_in_Harry_Potter
# Tool_pusher
# Syn_and_anti_addition
# Cultural_institutions
# Group_technology
# The_Other_Side_of_the_Sky:_A_Memoir
# Arc_elasticity
# Cultural_lag

# %%
hrpv = df.set_index('page_title').loc[rpv.head(20).index]

# %%
mr = df.set_index('page_title').loc[r.head(20).index].reset_index() # most rated

# %%
revs = mr.sort(['page_rate_count', 'page_title', 'rev_id', 'datetime']).groupby(['page_title','rev_id'])

# %%
means = revs.mean().reset_index()

# %%
means['nth_version'] = means.groupby(['page_title']).rev_id.cumcount() + 1

# %%
means[['page_title', 'rev_id', 'nth_rating', 'nth_version']].tail(100)
# Out:
#                                      page_title     rev_id  nth_rating  \
# 2316                       Thirteen_Reasons_Why  494230135         4.0
# 2317                       Thirteen_Reasons_Why  496042368         1.0
# 2318                       Thirteen_Reasons_Why  496042514         1.0
# 2319                       Thirteen_Reasons_Why  496042808         1.0
# 2320                       Thirteen_Reasons_Why  496210140         1.0
# 2321                       Thirteen_Reasons_Why  496425242         3.0
# 2322                       Thirteen_Reasons_Why  497718059         1.5
# 2323                       Thirteen_Reasons_Why  497751964         2.5
# 2324                       Thirteen_Reasons_Why  498931832         1.5
# 2325                       Thirteen_Reasons_Why  499094874         1.0
# 2326                       Thirteen_Reasons_Why  499533868         2.0
# 2327                       Thirteen_Reasons_Why  500362094         2.0
# 2328                       Thirteen_Reasons_Why  500908655         3.5
# 2329           Ultra-high-definition_television  441055808         1.0
# 2330           Ultra-high-definition_television  442655228         4.5
# 2331           Ultra-high-definition_television  447052454         1.0
# 2332           Ultra-high-definition_television  447324961         1.0
# 2333           Ultra-high-definition_television  447528746         1.0
# 2334           Ultra-high-definition_television  451449835         5.5
# 2335           Ultra-high-definition_television  459083961         1.0
# 2336           Ultra-high-definition_television  459173961         2.0
# 2337           Ultra-high-definition_television  461109204         1.5
# 2338           Ultra-high-definition_television  463634856         1.0
# 2339           Ultra-high-definition_television  463803421         1.5
# 2340           Ultra-high-definition_television  467078924         5.5
# 2341           Ultra-high-definition_television  469408903        14.5
# 2342           Ultra-high-definition_television  470666597         1.0
# 2343           Ultra-high-definition_television  470812725         3.0
# 2344           Ultra-high-definition_television  471620680        22.0
# 2345           Ultra-high-definition_television  472360451        20.5
# 2346           Ultra-high-definition_television  476065286         1.0
# 2347           Ultra-high-definition_television  476945490         3.5
# 2348           Ultra-high-definition_television  477659481         7.5
# 2349           Ultra-high-definition_television  483271090         1.5
# 2350           Ultra-high-definition_television  484657965        22.5
# 2351           Ultra-high-definition_television  486189140         1.5
# 2352           Ultra-high-definition_television  487213809         1.0
# 2353           Ultra-high-definition_television  488077624         1.5
# 2354           Ultra-high-definition_television  489227714         1.5
# 2355           Ultra-high-definition_television  489423611         1.0
# 2356           Ultra-high-definition_television  490070071        13.0
# 2357           Ultra-high-definition_television  493127930         1.0
# 2358           Ultra-high-definition_television  494807765         1.5
# 2359           Ultra-high-definition_television  496637115         1.5
# 2360           Ultra-high-definition_television  496855305         1.0
# 2361           Ultra-high-definition_television  497432003         1.5
# 2362           Ultra-high-definition_television  498483715         1.0
# 2363           Ultra-high-definition_television  498702845         3.0
# 2364  United_States_Declaration_of_Independence  440924612         1.0
# 2365  United_States_Declaration_of_Independence  441174192         2.0
# 2366  United_States_Declaration_of_Independence  442794753         1.0
# 2367  United_States_Declaration_of_Independence  443013160         1.5
# 2368  United_States_Declaration_of_Independence  443678194         1.0
# 2369  United_States_Declaration_of_Independence  444475515         3.0
# 2370  United_States_Declaration_of_Independence  445183037         1.5
# 2371  United_States_Declaration_of_Independence  445311436         4.0
# 2372  United_States_Declaration_of_Independence  447303909         2.0
# 2373  United_States_Declaration_of_Independence  448533883         1.0
# 2374  United_States_Declaration_of_Independence  449425041         1.5
# 2375  United_States_Declaration_of_Independence  449895079         1.5
#                                             ...        ...         ...
#
#       nth_version
# 2316          117
# 2317          118
# 2318          119
# 2319          120
# 2320          121
# 2321          122
# 2322          123
# 2323          124
# 2324          125
# 2325          126
# 2326          127
# 2327          128
# 2328          129
# 2329            1
# 2330            2
# 2331            3
# 2332            4
# 2333            5
# 2334            6
# 2335            7
# 2336            8
# 2337            9
# 2338           10
# 2339           11
# 2340           12
# 2341           13
# 2342           14
# 2343           15
# 2344           16
# 2345           17
# 2346           18
# 2347           19
# 2348           20
# 2349           21
# 2350           22
# 2351           23
# 2352           24
# 2353           25
# 2354           26
# 2355           27
# 2356           28
# 2357           29
# 2358           30
# 2359           31
# 2360           32
# 2361           33
# 2362           34
# 2363           35
# 2364            1
# 2365            2
# 2366            3
# 2367            4
# 2368            5
# 2369            6
# 2370            7
# 2371            8
# 2372            9
# 2373           10
# 2374           11
# 2375           12
#               ...
#
# [100 rows x 4 columns]

# %%
means.set_index(['page_title','nth_version']).rating_all_mean.plot()

# %%
panel = means.set_index(['page_title', 'nth_version']).to_panel()

# %%
means
# Out:
#          page_title     rev_id  Unnamed: 0  nth_rating  page_id  logged_in  \
# 0   Abraham_Lincoln  440005265      8475.0         1.0      307   0.000000
# 1   Abraham_Lincoln  440911206      9977.0         1.0      307   0.000000
# 2   Abraham_Lincoln  441298892     10555.0         1.0      307   0.000000
# 3   Abraham_Lincoln  441456897     10838.5         2.5      307   0.000000
# 4   Abraham_Lincoln  442117130     11973.0         4.0      307   0.000000
# 5   Abraham_Lincoln  442609796     12830.5         1.5      307   0.000000
# 6   Abraham_Lincoln  442784515     13148.0         2.0      307   0.000000
# 7   Abraham_Lincoln  443019560     13448.0         2.0      307   0.000000
# 8   Abraham_Lincoln  443139975     13606.0         1.0      307   0.000000
5.000000  5.000000  5.000000  5.000000          4.000000         5.000000
# 45  2.500000  3.000000  2.500000  3.000000          4.000000         2.500000
# 46  4.000000  4.000000  5.000000  4.000000          4.000000         4.000000
# 47  4.000000  3.000000  4.000000  5.000000          2.500000         4.000000
# 48  4.000000  5.000000  5.000000  4.000000          2.500000         4.000000
# 49  5.000000  5.000000  5.000000  5.000000          4.000000         5.000000
# 50  4.000000  5.000000  5.000000  5.000000          4.000000         4.500000
# 51  4.500000  4.500000  5.000000  4.500000          4.000000         4.500000
# 52  4.000000  5.000000  1.000000  4.000000          4.000000         3.000000
# 53  1.000000  1.000000  1.000000  1.000000          4.000000         1.000000
# 54       NaN       NaN       NaN  5.000000          1.000000         5.000000
# 55  5.000000  5.000000  5.000000  5.000000          4.000000         5.000000
# 56  5.000000  5.000000  5.000000  5.000000          4.000000         5.000000
# 57       NaN       NaN       NaN  1.000000          1.000000         1.000000
# 58  5.000000  5.000000  5.000000  5.000000          4.000000         5.000000
# 59  4.750000  5.000000  4.250000  5.000000          4.000000         4.500000
#          ...       ...       ...       ...               ...              ...
#
#     rating_all_mean  page_rate_count  rev_rate_count  page_comp_mean  \
# 0               NaN             1389               1        3.844368
# 1          5.000000             1389               1        3.844368
# 2          1.000000             1389               1        3.844368
# 3          4.250000             1389               4        3.844368
# 4          5.000000             1389               7        3.844368
# 5               NaN             1389               2        3.844368
# 6          4.000000             1389               3        3.844368
# 7          4.875000             1389               3        3.844368
# 8               NaN             1389               1        3.844368
# 9          4.812500             1389              31        3.844368
# 10         3.406250             1389               9        3.844368
# 11         4.375000             1389               2        3.844368
# 12         1.000000             1389               1        3.844368
# 13         2.750000             1389               2        3.844368
# 14         4.150000             1389               5        3.844368
# 15         5.000000             1389               1        3.844368
# 16              NaN             1389               2        3.844368
# 17         4.083333             1389               3        3.844368
# 18         5.000000             1389               2        3.844368
# 19         4.375000             1389               5        3.844368
# 20         2.250000             1389               1        3.844368
# 21         4.083333             1389              29        3.844368
# 22         5.000000             1389               1        3.844368
# 23         1.000000             1389               1        3.844368
# 24         5.000000             1389               1        3.844368
# 25              NaN             1389               1        3.844368
# 26         2.750000             1389               1        3.844368
# 27         3.442308             1389              18        3.844368
# 28         3.366667             1389              19        3.844368
# 29              NaN             1389               1        3.844368
# 30         4.000000             1389               3        3.844368
# 31              NaN             1389               1        3.844368
# 32         3.250000             1389               1        3.844368
# 33         4.687500             1389               6        3.844368
# 34         4.291667             1389               7        3.844368
# 35         3.708333             1389               6        3.844368
# 36         2.750000             1389               2        3.844368
# 37         3.729167             1389              13        3.844368
# 38         4.000000             1389               2        3.844368
# 39         5.000000             1389               3        3.844368
# 40         4.666667             1389               4        3.844368
# 41         3.020833             1389              14        3.844368
# 42         2.625000             1389               2        3.844368
# 43              NaN             1389               1        3.844368
# 44         5.000000             1389               1        3.844368
# 45         2.750000             1389               2        3.844368
# 46         4.250000             1389               1        3.844368
# 47         3.750000             1389               2        3.844368
# 48         4.500000             1389               2        3.844368
# 49         5.000000             1389               1        3.844368
# 49       5.000000       3.629468      5.000000         3.757627 ...
# 50       4.000000       3.629468      5.000000         3.757627 ...
# 51       4.500000       3.629468      4.500000         3.757627 ...
# 52       4.000000       3.629468      5.000000         3.757627 ...
# 53       1.000000       3.629468      1.000000         3.757627 ...
# 54            NaN       3.629468           NaN         3.757627 ...
# 55       5.000000       3.629468      5.000000         3.757627 ...
# 56       5.000000       3.629468      5.000000         3.757627 ...
# 57            NaN       3.629468           NaN         3.757627 ...
# 58       5.000000       3.629468      5.000000         3.757627 ...
# 59       4.750000       3.629468      5.000000         3.757627 ...
#               ...            ...           ...              ...
#
# [2416 rows x 24 columns]

# %%
panel['rev_rate_count'].gt(4)
# Out:
# nth_version                                      1      2      3      4   \
# page_title
# Abraham_Lincoln                               False  False  False  False
# Arithmetic_progression                         True   True   True   True
# Business_development                           True   True  False  False
# Dhirubhai_Ambani                              False   True   True  False
# Electromagnet                                 False  False   True   True
# Grand_Duchess_Anastasia_Nikolaevna_of_Russia   True  False  False  False
# House_of_Night                                False  False   True   True
# Jung_Yong-hwa                                 False  False  False   True
# Knights_Templar                               False   True   True   True
# Lisa_Brennan-Jobs                              True  False   True  False
# List_of_spells_in_Harry_Potter                False   True   True   True
# Marilyn_Monroe                                 True  False  False  False
# OSI_model                                      True  False  False   True
# Reserve_Bank_of_India                         False  False  False  False
# Silk_Road                                     False  False  False  False
# The_Hunger_Games                               True  False  False  False
# Thermoplastic                                  True   True  False  False
# Thirteen_Reasons_Why                           True   True  False  False
# Ultra-high-definition_television              False   True  False  False
# United_States_Declaration_of_Independence     False  False  False  False
#
# nth_version                                      5      6      7      8   \
# page_title
# Abraham_Lincoln                                True  False  False  False
# Arithmetic_progression                        False   True   True   True
# Business_development                           True   True  False  False
# Dhirubhai_Ambani                              False   True   True   True
# Electromagnet                                 False   True  False  False
# Grand_Duchess_Anastasia_Nikolaevna_of_Russia  False   True   True  False
# House_of_Night                                 True  False   True  False
# Jung_Yong-hwa                                  True   True  False  False
# Knights_Templar                               False  False   True  False
# Lisa_Brennan-Jobs                             False   True  False  False
# List_of_spells_in_Harry_Potter                 True   True   True   True
# Marilyn_Monroe                                 True  False  False  False
# OSI_model                                     False   True   True  False
# Reserve_Bank_of_India                         False  False  False   True
# Silk_Road                                     False  False  False   True
# The_Hunger_Games                              False  False   True  False
# Thermoplastic                                  True  False  False  False
# Thirteen_Reasons_Why                          False   True  False  False
# Ultra-high-definition_television              False   True  False  False
# United_States_Declaration_of_Independence     False   True  False   True
#
# nth_version                                      9      10     11     12  \
# page_title
# Abraham_Lincoln                               False   True   True  False
# Arithmetic_progression                        False   True   True  False
# Business_development                           True   True   True  False
# Dhirubhai_Ambani                              False   True  False   True
# Electromagnet                                  True  False  False  False
# Grand_Duchess_Anastasia_Nikolaevna_of_Russia  False   True  False  False
# House_of_Night                                False  False  False   True
# Jung_Yong-hwa                                 False  False  False  False
# Knights_Templar                               False  False  False   True
# Lisa_Brennan-Jobs                             False  False  False  False
# List_of_spells_in_Harry_Potter                 True   True   True  False
# Marilyn_Monroe                                False  False  False  False
# OSI_model                                      True  False  False  False
# Reserve_Bank_of_India                          True  False  False   True
# Silk_Road                                      True  False  False  False
# The_Hunger_Games                              False   True   True  False
# Thermoplastic                                 False   True   True  False
# Thirteen_Reasons_Why                          False   True  False  False
# Ultra-high-definition_television              False  False  False   True
# United_States_Declaration_of_Independence     False  False  False  False
#
# nth_version                                      13     14     15     16  \
# page_title
# Abraham_Lincoln                               False  False   True  False
# Arithmetic_progression                        False   True   True   True
# Business_development                           True  False   True  False
# Dhirubhai_Ambani                               True   True   True   True
# Electromagnet                                  True  False  False   True
# Grand_Duchess_Anastasia_Nikolaevna_of_Russia  False  False  False  False
# House_of_Night                                False  False  False   True
# Jung_Yong-hwa                                 False  False   True   True
# Knights_Templar                               False   True  False   True
# Lisa_Brennan-Jobs                              True  False   True  False
# List_of_spells_in_Harry_Potter                 True   True   True   True
# Marilyn_Monroe                                False  False  False  False
# OSI_model                                      True   True   True  False
# Reserve_Bank_of_India                          True  False  False  False
# Silk_Road                                     False  False  False  False
# The_Hunger_Games                              False  False  False  False
# Thermoplastic                                 False   True  False   True
# Thirteen_Reasons_Why                          False  False  False  False
# Ultra-high-definition_television               True  False   True   True
# United_States_Declaration_of_Independence     False  False  False  False
#
# nth_version                                      17     18     19     20
# page_title
# Abraham_Lincoln                               False  False  False   True ...
# Arithmetic_progression                        False   True   True   True ...
# Business_development                           True  False  False  False ...
# Dhirubhai_Ambani                              False  False  False  False ...
# Electromagnet                                 False  False  False   True ...
# Grand_Duchess_Anastasia_Nikolaevna_of_Russia  False   True  False  False ...
# House_of_Night                                False   True  False  False ...
# Jung_Yong-hwa                                 False  False  False   True ...
# Knights_Templar                               False  False   True  False ...
# Lisa_Brennan-Jobs                             False   True  False   True ...
# List_of_spells_in_Harry_Potter                False   True   True   True ...
# Marilyn_Monroe                                 True  False  False  False ...
# OSI_model                                     False  False  False  False ...
# Reserve_Bank_of_India                         False  False  False  False ...
# Silk_Road                                     False  False  False  False ...
# The_Hunger_Games                              False  False  False  False ...
# Thermoplastic                                  True  False  False   True ...
# Thirteen_Reasons_Why                           True  False  False  False ...
# Ultra-high-definition_television               True  False   True   True ...
# United_States_Declaration_of_Independence      True  False  False  False ...
#
# [20 rows x 580 columns]

# %%
panel['rating_all_mean'][panel['rev_rate_count'].gt(3)].transpose().plot(
    legend=False, figsize=(20,40), subplots=True, sharex=True, sharey=True)
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0x12b6e3690>,
#        <matplotlib.axes.AxesSubplot object at 0x13060a090>,
#        <matplotlib.axes.AxesSubplot object at 0x13062f9d0>,
#        <matplotlib.axes.AxesSubplot object at 0x13068ca50>,
#        <matplotlib.axes.AxesSubplot object at 0x1306b07d0>,
#        <matplotlib.axes.AxesSubplot object at 0x130b96990>,
#        <matplotlib.axes.AxesSubplot object at 0x130bb3bd0>,
#        <matplotlib.axes.AxesSubplot object at 0x130f1b510>,
#        <matplotlib.axes.AxesSubplot object at 0x130f02a90>,
#        <matplotlib.axes.AxesSubplot object at 0x130f5c5d0>,
#        <matplotlib.axes.AxesSubplot object at 0x130f82a10>,
#        <matplotlib.axes.AxesSubplot object at 0x130fa1110>,
#        <matplotlib.axes.AxesSubplot object at 0x130fc47d0>,
#        <matplotlib.axes.AxesSubplot object at 0x130fd76d0>,
#        <matplotlib.axes.AxesSubplot object at 0x131008610>,
#        <matplotlib.axes.AxesSubplot object at 0x13102f7d0>,
#        <matplotlib.axes.AxesSubplot object at 0x130fb3410>,
#        <matplotlib.axes.AxesSubplot object at 0x13106fe50>,
#        <matplotlib.axes.AxesSubplot object at 0x13301a2d0>,
#        <matplotlib.axes.AxesSubplot object at 0x133035910>], dtype=object)

# %%
mr['nth_version'] = mr.groupby(['page_title','rev_id']).rev_id.cumcount()

# %%
mr['nth_version'] = mr.groupby.cumcount() + 1

# %%
mr[['page_title', 'rev_id', 'nth_rating', 'nth_version']]
# Out:
#           page_title     rev_id  nth_rating  nth_version
# 0   The_Hunger_Games  440748476           1            0
# 1   The_Hunger_Games  440748476           2            1
# 2   The_Hunger_Games  440748476           3            2
# 3   The_Hunger_Games  440748476           4            3
# 4   The_Hunger_Games  440748476           5            4
# 5   The_Hunger_Games  440748476           6            5
# 6   The_Hunger_Games  440748476           7            6
# 7   The_Hunger_Games  440748476           8            7
# 8   The_Hunger_Games  440748476           9            8
# 9   The_Hunger_Games  440748476          10            9
# 10  The_Hunger_Games  440748476          11           10
# 11  The_Hunger_Games  440748476          12           11
# 12  The_Hunger_Games  441647191           1            0
# 13  The_Hunger_Games  441647191           2            1
# 14  The_Hunger_Games  441647191           3            2
# 15  The_Hunger_Games  441647191           4            3
# 16  The_Hunger_Games  441969241           1            0
# 17  The_Hunger_Games  441969241           2            1
# 18  The_Hunger_Games  442080660           1            0
# 19  The_Hunger_Games  442080660           2            1
# 20  The_Hunger_Games  442080660           3            2
# 21  The_Hunger_Games  442080660           4            3
# 22  The_Hunger_Games  442291473           1            0
# 23  The_Hunger_Games  442378635           1            0
# 24  The_Hunger_Games  442378635           2            1
# 25  The_Hunger_Games  442378635           3            2
# 26  The_Hunger_Games  442556158           1            0
# 27  The_Hunger_Games  442556158           2            1
# 28  The_Hunger_Games  442556158           3            2
# 29  The_Hunger_Games  442556158           4            3
# 30  The_Hunger_Games  442556158           5            4
# 31  The_Hunger_Games  443009541           1            0
# 32  The_Hunger_Games  443009541           2            1
# 33  The_Hunger_Games  443211510           1            0
# 34  The_Hunger_Games  443211510           2            1
# 35  The_Hunger_Games  443466895           1            0
# 36  The_Hunger_Games  443466895           2            1
# 37  The_Hunger_Games  443466895           3            2
# 38  The_Hunger_Games  443466895           4            3
# 39  The_Hunger_Games  443466895           5            4
# 40  The_Hunger_Games  443755858           1            0
# 41  The_Hunger_Games  443755858           2            1
# 42  The_Hunger_Games  443755858           3            2
# 43  The_Hunger_Games  443755858           4            3
# 44  The_Hunger_Games  443755858           5            4
# 45  The_Hunger_Games  444128194           1            0
# 46  The_Hunger_Games  444128194           2            1
# 47  The_Hunger_Games  444386631           1            0
# 48  The_Hunger_Games  444386631           2            1
# 49  The_Hunger_Games  444386631           3            2
# 50  The_Hunger_Games  444386631           4            3
# 51  The_Hunger_Games  444719126           1            0
# 52  The_Hunger_Games  444719126           2            1
# 53  The_Hunger_Games  444931877           1            0
# 54  The_Hunger_Games  444931877           2            1
# 55  The_Hunger_Games  444931877           3            2
# 56  The_Hunger_Games  445051420           1            0
# 57  The_Hunger_Games  445088983           1            0
# 58  The_Hunger_Games  445113771           1            0
# 59  The_Hunger_Games  445189782           1            0
#                  ...        ...         ...          ...
#
# [12681 rows x 4 columns]

# %%
p.rpv.value_counts()
# Out:
# 1.000000    5528
# 2.000000    1061
# 1.500000     579
# 3.000000     313
# 1.333333     266
# 1.666667     166
# 2.500000     127
# 4.000000     118
# 1.250000     111
# 1.750000      68
# 5.000000      66
# 1.400000      57
# 2.333333      56
# 3.500000      55
# 2.666667      52
# ...
# 2.058824     1
# 2.585714     1
# 2.272727     1
# 2.960000     1
# 7.771429     1
# 4.142857     1
# 3.145833     1
# 2.969697     1
# 1.377778     1
# 1.789474     1
# 2.307692     1
# 9.666667     1
# 13.200000    1
# 2.340426     1
# 4.115385     1
# Length: 471, dtype: int64

# %%
r.value_counts().sort_index().iloc[0:50].plot(kind='bar', xscale=)

# %%
df
# Out:
#     Unnamed: 0     rev_id  nth_rating  page_id       page_title  logged_in  \
# 0         8475  440005265           1      307  Abraham_Lincoln          0
# 1         9977  440911206           1      307  Abraham_Lincoln          0
# 2        10555  441298892           1      307  Abraham_Lincoln          0
# 3        10837  441456897           1      307  Abraham_Lincoln          0
# 4        10838  441456897           2      307  Abraham_Lincoln          0
# 5        10839  441456897           3      307  Abraham_Lincoln          0
# 6        10840  441456897           4      307  Abraham_Lincoln          0
# 7        11970  442117130           1      307  Abraham_Lincoln          0
# 8        11971  442117130           2      307  Abraham_Lincoln          0
# 9        11972  442117130           3      307  Abraham_Lincoln          0
# 10       11973  442117130           4      307  Abraham_Lincoln          0
# 11       11974  442117130           5      307  Abraham_Lincoln          0
# 12       11975  442117130           6      307  Abraham_Lincoln          0
# 13       11976  442117130           7      307  Abraham_Lincoln          0
# 14       12830  442609796           1      307  Abraham_Lincoln          0
# 15       12831  442609796           2      307  Abraham_Lincoln          0
# 16       13147  442784515           1      307  Abraham_Lincoln          0
# 17       13148  442784515           2      307  Abraham_Lincoln          0
# 18       13149  442784515           3      307  Abraham_Lincoln          0
# 19       13447  443019560           1      307  Abraham_Lincoln          0
# 20       13448  443019560           2      307  Abraham_Lincoln          0
# 21       13449  443019560           3      307  Abraham_Lincoln          0
# 22       13606  443139975           1      307  Abraham_Lincoln          0
# 23       14009  443407586           1      307  Abraham_Lincoln          0
# 24       14010  443407586           2      307  Abraham_Lincoln          0
# 25       14011  443407586           3      307  Abraham_Lincoln          0
# 26       14012  443407586           4      307  Abraham_Lincoln          0
# 27       14013  443407586           5      307  Abraham_Lincoln          0
# 28       14014  443407586           6      307  Abraham_Lincoln          0
# 29       14015  443407586           7      307  Abraham_Lincoln          0
# 13                5              NaN             1389               7
# 14                5              NaN             1389               2
# 15                1              NaN             1389               2
# 16                3             3.75             1389               3
# 17                4             4.25             1389               3
# 18                4              NaN             1389               3
# 19                4             4.75             1389               3
# 20                5              NaN             1389               3
# 21                5             5.00             1389               3
# 22                5              NaN             1389               1
# 23                5             5.00             1389              31
# 24              NaN              NaN             1389              31
# 25                5             5.00             1389              31
# 26                2              NaN             1389              31
# 27                2              NaN             1389              31
# 28                2              NaN             1389              31
# 29                2              NaN             1389              31
# 30                4              NaN             1389              31
# 31              NaN              NaN             1389              31
# 32                4              NaN             1389              31
# 33                4              NaN             1389              31
# 34                3              NaN             1389              31
# 35                4              NaN             1389              31
# 36                2              NaN             1389              31
# 37                3              NaN             1389              31
# 38                3              NaN             1389              31
# 39                4              NaN             1389              31
# 40                5              NaN             1389              31
# 41                4              NaN             1389              31
# 42                4              NaN             1389              31
# 43                2              NaN             1389              31
# 44                3              NaN             1389              31
# 45                4              NaN             1389              31
# 46                2              NaN             1389              31
# 47                5              NaN             1389              31
# 48                1              NaN             1389              31
# 49                4              NaN             1389              31
# 50                3              NaN             1389              31
# 51                4             4.25             1389              31
# 52                5             5.00             1389              31
# 53                5              NaN             1389              31
# 54                3             3.75             1389               9
# 55                1             1.00             1389               9
# 56                2             2.75             1389               9
# 57                3             3.00             1389               9
# 58                3             3.25             1389               9
# 59                5             5.00             1389               9
#                 ...              ...              ...             ...
#
#     page_comp_mean  rev_comp_mean  page_obj_mean  rev_obj_mean
# 0         3.844368            NaN       3.629468      1.000000 ...
# 1         3.844368       5.000000       3.629468      5.000000 ...
# 2         3.844368       1.000000       3.629468      1.000000 ...
# 3         3.844368       4.333333       3.629468      4.000000 ...
# 4         3.844368       4.333333       3.629468      4.000000 ...
# 5         3.844368       4.333333       3.629468      4.000000 ...
# 6         3.844368       4.333333       3.629468      4.000000 ...
# 7         3.844368       5.000000       3.629468      4.000000 ...
# 8         3.844368       5.000000       3.629468      4.000000 ...
# 9         3.844368       5.000000       3.629468      4.000000 ...
# 10        3.844368       5.000000       3.629468      4.000000 ...
# 11        3.844368       5.000000       3.629468      4.000000 ...
# 12        3.844368       5.000000       3.629468      4.000000 ...
# 13        3.844368       5.000000       3.629468      4.000000 ...
# 14        3.844368            NaN       3.629468      1.000000 ...
# 15        3.844368            NaN       3.629468      1.000000 ...
# 16        3.844368       4.333333       3.629468      3.333333 ...
# 17        3.844368       4.333333       3.629468      3.333333 ...
# 18        3.844368       4.333333       3.629468      3.333333 ...
# 19        3.844368       5.000000       3.629468      4.500000 ...
# 20        3.844368       5.000000       3.629468      4.500000 ...
# 21        3.844368       5.000000       3.629468      4.500000 ...
# 22        3.844368            NaN       3.629468           NaN ...
# 23        3.844368       4.307692       3.629468      3.200000 ...
# 24        3.844368       4.307692       3.629468      3.200000 ...
# 25        3.844368       4.307692       3.629468      3.200000 ...
# 26        3.844368       4.307692       3.629468      3.200000 ...
# 27        3.844368       4.307692       3.629468      3.200000 ...
# 28        3.844368       4.307692       3.629468      3.200000 ...
#           1.22140000e+03,   1.24852000e+03,   1.27564000e+03,
#           1.30276000e+03,   1.32988000e+03,   1.35700000e+03,
#           1.38412000e+03,   1.41124000e+03,   1.43836000e+03,
#           1.46548000e+03,   1.49260000e+03,   1.51972000e+03,
#           1.54684000e+03,   1.57396000e+03,   1.60108000e+03,
#           1.62820000e+03,   1.65532000e+03,   1.68244000e+03,
#           1.70956000e+03,   1.73668000e+03,   1.76380000e+03,
#           1.79092000e+03,   1.81804000e+03,   1.84516000e+03,
#           1.87228000e+03,   1.89940000e+03,   1.92652000e+03,
#           1.95364000e+03,   1.98076000e+03,   2.00788000e+03,
#           2.03500000e+03,   2.06212000e+03,   2.08924000e+03,
#           2.11636000e+03,   2.14348000e+03,   2.17060000e+03,
#           2.19772000e+03,   2.22484000e+03,   2.25196000e+03,
#           2.27908000e+03,   2.30620000e+03,   2.33332000e+03,
#           2.36044000e+03,   2.38756000e+03,   2.41468000e+03,
#           2.44180000e+03,   2.46892000e+03,   2.49604000e+03,
#           2.52316000e+03,   2.55028000e+03,   2.57740000e+03,
#           2.60452000e+03,   2.63164000e+03,   2.65876000e+03,
#           2.68588000e+03,   2.71300000e+03]),
#  <a list of 100 Patch objects>)

# %%
foo = df.set_index(['page_title','rev_id']).filter(like='mean', axis=1)

# %%
mr.boxplot(
    column='rating_all_mean', by=['page_title','nth_version'], figsize=(20,10), subplots=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-397-6f8a5be094d8> in <module>()
#       1 mr.boxplot(
# ----> 2     column='rating_all_mean', by=['page_title','nth_version'], figsize=(20,10), subplots=True)
#
# /Users/bkarfunkel/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in boxplot(self, column, by, ax, fontsize, rot, grid, **kwds)
#    4832     import matplotlib.pyplot as plt
#    4833     ax = plots.boxplot(self, column=column, by=by, ax=ax,
# -> 4834                        fontsize=fontsize, grid=grid, rot=rot, **kwds)
#    4835     plt.draw_if_interactive()
#    4836     return ax
#
# /Users/bkarfunkel/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, **kwds)
#    1901         fig, axes = _grouped_plot_by_column(plot_group, data, columns=columns,
#    1902                                             by=by, grid=grid, figsize=figsize,
# -> 1903                                             ax=ax)
#    1904
#    1905         # Return axes in multiplot case, maybe revisit later # 985
#
# /Users/bkarfunkel/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _grouped_plot_by_column(plotf, data, columns, by, numeric_only, grid, figsize, ax, **kwargs)
#    2315         ax = ravel_axes[i]
#    2316         gp_col = grouped[col]
# -> 2317         plotf(gp_col, ax, **kwargs)
#    2318         ax.set_title(col)
#    2319         ax.set_xlabel(com.pprint_thing(by))
#
# /Users/bkarfunkel/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_group(grouped, ax)
#    1879         keys = [com.pprint_thing(x) for x in keys]
#    1880         values = [remove_na(v) for v in values]
# -> 1881         bp = ax.boxplot(values, **kwds)
#    1882         if kwds.get('vert', 1):
#    1883             ax.set_xticklabels(keys, rotation=rot, fontsize=fontsize)
#
# TypeError: boxplot() got an unexpected keyword argument 'subplots'

# %% [markdown]
# --------------------
# ## Open Questions ##
#
# + Are pages with a high edit velocity different than other pages?
# + Are ratings more/less reliable for pages with lots of ratings per version?
# + Are lists different than other pages?
#     + Is completeness more relevant for lists, e.g.?
